# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading Data
data = pd.read_csv('population.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf4 in position 1: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-09cb393c66b1> in <module>
#       1 # Reading Data
# ----> 2 data = pd.read_csv('population.csv')
#       3 data.head()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf4 in position 1: invalid continuation byte

# %% [markdown]
# ### Exploring Data

# %%
data.shape
# Out:
# (988, 14)

# %%
data.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (FAO)', 'Area', 'Element Code',
#        'Element', 'Item Code (FAO)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988 entries, 0 to 987
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       988 non-null    object
#  1   Domain            988 non-null    object
#  2   Area Code (FAO)   988 non-null    int64
#  3   Area              988 non-null    object
#  4   Element Code      988 non-null    int64
#  5   Element           988 non-null    object
#  6   Item Code (FAO)   988 non-null    int64
#  7   Item              988 non-null    object
#  8   Year Code         988 non-null    int64
#  9   Year              988 non-null    int64
#  10  Unit              988 non-null    object
#  11  Value             988 non-null    int64
#  12  Flag              15 non-null     object
#  13  Flag Description  988 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 108.2+ KB

# %%
data.describe()
# Out:
#        Area Code (FAO)  Element Code  Item Code (FAO)  Year Code    Year  \
# count            988.0    988.000000       988.000000      988.0   988.0
# mean             165.0   5753.487854       554.558704     2018.0  2018.0
# std                0.0    149.674618       347.582882        0.0     0.0
# min              165.0   5607.000000        15.000000     2018.0  2018.0
# 25%              165.0   5610.000000       249.000000     2018.0  2018.0
# 50%              165.0   5622.000000       526.000000     2018.0  2018.0
# 75%              165.0   5910.000000       837.000000     2018.0  2018.0
# max              165.0   5922.000000      1296.000000     2018.0  2018.0
#
#               Value
# count  9.880000e+02
# mean   3.998367e+04
# std    2.476227e+05
# min    0.000000e+00
# 25%    2.375000e+01
# 50%    4.335000e+02
# 75%    5.364250e+03
# max    3.912607e+06

# %%
data.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (FAO)', 'Area', 'Element Code',
#        'Element', 'Item Code (FAO)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description'],
#       dtype='object')

# %%
data.groupby("Element").mean()
# Out:
#                  Area Code (FAO)  Element Code  Item Code (FAO)  Year Code  \
# Element
# Export Quantity            165.0   5909.942982       561.912281     2018.0
# Export Value               165.0   5922.000000       558.151111     2018.0
# Import Quantity            165.0   5609.951673       551.702602     2018.0
# Import Value               165.0   5622.000000       548.105263     2018.0
#
#                    Year         Value
# Element
# Export Quantity  2018.0  66160.644737
# Export Value     2018.0  29068.733333
# Import Quantity  2018.0  38289.509294
# Import Value     2018.0  28492.078947
