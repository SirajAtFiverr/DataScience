# %% [markdown]
# # Expolatory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exploring Data

# %%
# Reading DataSet
data = pd.read_csv('covid.csv')
data.head()
# Out:
#          Date  Deaths  Recoveries  Total
# 0  2020-02-26     NaN         NaN      2
# 1  2020-02-29     NaN         NaN      4
# 2  2020-03-03     NaN         NaN      5
# 3  2020-03-04     NaN         NaN      5
# 4  2020-03-05     NaN         NaN      6

# %%
data.shape
# Out:
# (594, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        594 non-null    object
#  1   Deaths      579 non-null    float64
#  2   Recoveries  589 non-null    float64
#  3   Total       594 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 18.7+ KB

# %%
data.describe()
# Out:
#              Deaths    Recoveries         Total
# count    579.000000  5.890000e+02  5.940000e+02
# mean   12063.350604  4.871839e+05  5.358178e+05
# std     8607.483741  3.590567e+05  3.830745e+05
# min        2.000000  1.000000e+00  2.000000e+00
# 25%     6104.500000  2.488730e+05  2.765500e+05
# 50%    10258.000000  4.238920e+05  4.683520e+05
# 75%    20502.500000  8.203740e+05  8.997810e+05
# max    28280.000000  1.210897e+06  1.265047e+06

# %%
# Column names
data.columns
# Out:
# Index(['Date', 'Deaths', 'Recoveries', 'Total'], dtype='object')

# %%
# Unique Values
data.nunique()
# Out:
# Date          594
# Deaths        577
# Recoveries    578
# Total         593
# dtype: int64

# %%
data['Deaths'].unique()
# Out:
# array([       nan, 2.0000e+00, 3.0000e+00, 5.0000e+00, 6.0000e+00,
#        7.0000e+00, 8.0000e+00, 9.0000e+00, 1.1000e+01, 1.3000e+01,
#        1.8000e+01, 2.5000e+01, 2.6000e+01, 3.1000e+01, 3.5000e+01,
#        3.6000e+01, 4.1000e+01, 4.5000e+01, 5.1000e+01, 5.5000e+01,
#        6.1000e+01, 6.3000e+01, 6.6000e+01, 8.6000e+01, 9.1000e+01,
#        9.3000e+01, 9.6000e+01, 1.1100e+02, 1.2800e+02, 1.3500e+02,
#        1.4400e+02, 1.6800e+02, 1.7600e+02, 2.0100e+02, 2.1200e+02,
#        2.3500e+02, 2.5300e+02, 2.6900e+02, 2.8100e+02, 2.9200e+02,
#        3.1200e+02, 3.4300e+02, 3.8500e+02, 4.1700e+02, 4.4000e+02,
#        4.6200e+02, 4.8600e+02, 5.1400e+02, 5.4400e+02, 5.8500e+02,
#        5.9900e+02, 6.3600e+02, 6.5900e+02, 6.6700e+02, 7.2400e+02,
#        7.3700e+02, 7.7000e+02, 8.0300e+02, 8.3400e+02, 8.7300e+02,
#        9.0300e+02, 9.3900e+02, 9.8500e+02, 1.0170e+03, 1.0670e+03,
#        1.1010e+03, 1.1330e+03, 1.1670e+03, 1.1970e+03, 1.2250e+03,
#        1.2600e+03, 1.3170e+03, 1.3950e+03, 1.4830e+03, 1.5430e+03,
#        1.6210e+03, 1.6880e+03, 1.7700e+03, 1.8380e+03, 1.9350e+03,
#        2.0020e+03, 2.0670e+03, 2.1720e+03, 2.2550e+03, 2.3560e+03,
#        2.4630e+03, 2.5510e+03, 2.6320e+03, 2.7290e+03, 2.8390e+03,
#        2.9750e+03, 3.0930e+03, 3.2290e+03, 3.3820e+03, 3.5010e+03,
#        3.5900e+03, 3.6950e+03, 3.7550e+03, 3.9030e+03, 3.9620e+03,
#        4.0350e+03, 4.1180e+03, 4.1670e+03, 4.3040e+03, 4.3950e+03,
#        2.1376e+04, 2.1453e+04, 2.1529e+04, 2.1576e+04, 2.1633e+04,
#        2.1689e+04, 2.1723e+04, 2.1782e+04, 2.1828e+04, 2.1874e+04,
#        2.1913e+04, 2.1940e+04, 2.1977e+04, 2.2007e+04, 2.2034e+04,
#        2.2073e+04, 2.2108e+04, 2.2152e+04, 2.2188e+04, 2.2211e+04,
#        2.2231e+04, 2.2254e+04, 2.2281e+04, 2.2321e+04, 2.2345e+04,
#        2.2379e+04, 2.2408e+04, 2.2427e+04, 2.2452e+04, 2.2469e+04,
#        2.2493e+04, 2.2520e+04, 2.2555e+04, 2.2582e+04, 2.2597e+04,
#        2.2618e+04, 2.2642e+04, 2.2689e+04, 2.2720e+04, 2.2760e+04,
#        2.2781e+04, 2.2811e+04, 2.2848e+04, 2.2888e+04, 2.2928e+04,
#        2.2939e+04, 2.2971e+04, 2.3016e+04, 2.3048e+04, 2.3087e+04,
#        2.3133e+04, 2.3209e+04, 2.3295e+04, 2.3360e+04, 2.3422e+04,
#        2.3462e+04, 2.3529e+04, 2.3575e+04, 2.3635e+04, 2.3702e+04,
#        2.3797e+04, 2.3865e+04, 2.3918e+04, 2.4004e+04, 2.4085e+04,
#        2.4187e+04, 2.4266e+04, 2.4339e+04, 2.4406e+04, 2.4478e+04,
#        2.4573e+04, 2.4639e+04, 2.4713e+04, 2.4783e+04, 2.4848e+04,
#        2.4923e+04, 2.5003e+04, 2.5094e+04, 2.5220e+04, 2.5320e+04,
#        2.5415e+04, 2.5535e+04, 2.5604e+04, 2.5670e+04, 2.5788e+04,
#        2.5889e+04, 2.5978e+04, 2.6035e+04, 2.6114e+04, 2.6175e+04,
#        2.6232e+04, 2.6330e+04, 2.6413e+04, 2.6497e+04, 2.6580e+04,
#        2.6662e+04, 2.6720e+04, 2.6787e+04, 2.6865e+04, 2.6938e+04,
#        2.7004e+04, 2.7072e+04, 2.7135e+04, 2.7206e+04, 2.7246e+04,
#        2.7327e+04, 2.7374e+04, 2.7432e+04, 2.7482e+04, 2.7524e+04,
#        2.7566e+04, 2.7597e+04, 2.7638e+04, 2.7690e+04, 2.7729e+04,
#        2.7785e+04, 2.7831e+04, 2.7866e+04, 2.7893e+04, 2.7947e+04,
#        2.7986e+04, 2.8032e+04, 2.8058e+04, 2.8087e+04, 2.8106e+04,
#        2.8134e+04, 2.8152e+04, 2.8173e+04, 2.8201e+04, 2.8228e+04,
#        2.8252e+04, 2.8269e+04, 2.8280e+04])

# %% [markdown]
# ## Cleaning And Filtering Data

# %% [markdown]
# ### Finding missing values

# %%
data.isnull().sum()
# Out:
# Date           0
# Deaths        15
# Recoveries     5
# Total          0
# dtype: int64

# %%
data.shape
# Out:
# (594, 4)

# %%
# Droping Column
# data.drop(['Deaths'], axis=1).head()

# %%
# Droping null values
data = data.dropna()

# %%
data.shape
# Out:
# (579, 4)

# %%
data.isnull().sum()
# Out:
# Date          0
# Deaths        0
# Recoveries    0
# Total         0
# dtype: int64

# %%
data = sns.load_dataset('titanic')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data = data.drop(['deck'], axis=1)

# %%
data = data.dropna()
data.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
data['sex'].value_counts()
# Out:
# male      453
# female    259
# Name: sex, dtype: int64
